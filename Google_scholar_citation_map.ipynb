# %%
pip install citation-map --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 49.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 64.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 54.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 476.0/476.0 kB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from citation_map import generate_citation_map

# 替换为你的Google Scholar ID
scholar_id = 'Nk2DzVcAAAAJ&hl=en&authuser=2'
generate_citation_map(scholar_id)
# Out:
# No cache found for this author. Running from scratch.
# WARNING:scholarly:Changing the scholar_id following redirect from Nk2DzVcAAAAJ&hl=en&authuser=2 to Nk2DzVcAAAAJ. To avoid this warning, use Nk2DzVcAAAAJ to look up this scholar.
# Author profile found, with 32 publications.
# Filling metadata for your 32 publications: 100%|██████████| 32/32 [00:12<00:00,  2.64it/s]
# Finding citing authors and papers on your 23 publications: 100%|██████████| 23/23 [00:07<00:00,  3.16it/s]
# A total of 125 citing authors recorded.
#
# Saved to cache: cache/Nk2DzVcAAAAJ&hl=en&authuser=2/all_citing_author_paper_tuple_list.pkl.
#
# Identifying affiliations using the aggressive approach.
# Finding citing affiliations from 125 citing authors: 100%|██████████| 125/125 [00:42<00:00,  2.97it/s]
# A total of 125 citing affiliations recorded.
#
# Taking the aggressive approach. Cleaning the affiliation names.
# List of all citing authors and affiliations before cleaning:
#
# ...
